# %% [markdown]
# Problem
# ------------
# Case: A product purchased atleast 3 times a day if we found association
#        of that product X e.g; 3 product would be bought in a row if X product
#        would bought.
#
# For Support
# -----------------
# purchase of product X of a day = 3
# purchase of product X of a week = 3x7 = 21
# transaction per week of product X = 7500
#     ∴ Support = 3x7/7500 = 0.0028 ≅ 0.003
#
# For Confidence
# ----------------------
# Possibility of association of product X with product Y is called confedence.
# Bydefault min. confidence is 80%(0.8) but we divideit by;
#     ∴ 0.8/4 = 0.2(20%)
#
# Lift
# -----
# The ratio of Confidence and Support is called lift.
#     ∴ Best min. lift = 3
#
# Note: This also depends upon business problem to choose Lift values.

# %%
# Step 1: Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Step 2: Importing the dataset
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header=None)

# Step 2(a): Preprocesing data to fit model
"""
transactions = []
for sublist in dataset.values.tolist():    
    print(sublist)    #  ['mineral water', nan, nan,......, nan]
    clean_sublist = [item for item in sublist if item is not np.nan]  # ['mineral water']
    transactions.append(clean_sublist) # remove 'nan' values # https://github.com/rasbt/mlxtend/issues/433
"""
        
transactions = [
            [product for product in products if product is not np.nan] 
            for products in dataset.values.tolist()]
[print(i) for i in transactions[:2]]
# Out:
# ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']
# ['burgers', 'meatballs', 'eggs']
# [None, None]

# %%
# Step 3: Training Apriori on the dataset
# Step 4: Sortted already with apriori module
from apyori import apriori
rules = apriori(transactions,       # 2D list that contain items of each customer of customers
                min_support=0.003,  # item/Transaction (I) /Total no. of items/Transactions
                min_confedence=0.2, # 20% posiility of association with products 
                min_lift=3,         # confidence/support = lift (higher is better) 
                min_length=2)       # Min. 2 products for association rule

# %%
# Steps 5: Visualization of result
rules = list(rules)
listRules = [list(rules[i][0]) for i in range(0,len(rules))]

# %%
listRules
# Out:
# [['brownies', 'cottage cheese'],
#  ['chicken', 'light cream'],
#  ['mushroom cream sauce', 'escalope'],
#  ['pasta', 'escalope'],
#  ['fresh bread', 'tomato juice'],
#  ['fresh tuna', 'honey'],
#  ['honey', 'fromage blanc'],
#  ['ground beef', 'herb & pepper'],
#  ['ground beef', 'tomato sauce'],
#  ['light cream', 'olive oil'],
#  ['olive oil', 'whole wheat pasta'],
#  ['pasta', 'shrimp'],
#  ['spaghetti', 'avocado', 'milk'],
#  ['nan', 'brownies', 'cottage cheese'],
#  ['burgers', 'milk', 'cake'],
#  ['burgers', 'turkey', 'chocolate'],
#  ['burgers', 'milk', 'turkey'],
#  ['tomatoes', 'frozen vegetables', 'cake'],
#  ['spaghetti', 'ground beef', 'cereals'],
#  ['ground beef', 'chicken', 'milk'],
#  ['chicken', 'light cream', 'nan'],
#  ['olive oil', 'chicken', 'milk'],
#  ['pancakes', 'chicken', 'milk'],
#  ['spaghetti', 'chicken', 'olive oil'],
#  ['frozen vegetables', 'shrimp', 'chocolate'],
#  ['ground beef', 'herb & pepper', 'chocolate'],
#  ['soup', 'milk', 'chocolate'],
#  ['spaghetti', 'cooking oil', 'ground beef'],
#  ['ground beef', 'eggs', 'herb & pepper'],
#  ['red wine', 'spaghetti', 'eggs'],
#  ['mushroom cream sauce', 'nan', 'escalope'],
#  ['pasta', 'nan', 'escalope'],
#  ['french fries', 'ground beef', 'herb & pepper'],
#  ['fresh bread', 'nan', 'tomato juice'],
#  ['nan', 'fresh tuna', 'honey'],
#  ['nan', 'honey', 'fromage blanc'],
#  ['tomatoes', 'green tea', 'frozen vegetables'],
#  ['spaghetti', 'ground beef', 'frozen vegetables'],
#  ['olive oil', 'frozen vegetables', 'milk'],
#  ['soup', 'frozen vegetables', 'milk'],
#  ['tomatoes', 'frozen vegetables', 'milk'],
#  ['frozen vegetables', 'mineral water', 'shrimp'],
#  ['spaghetti', 'frozen vegetables', 'olive oil'],
#  ['spaghetti', 'frozen vegetables', 'shrimp'],
#  ['tomatoes', 'frozen vegetables', 'shrimp'],
#  ['tomatoes', 'spaghetti', 'frozen vegetables'],
#  ['spaghetti', 'ground beef', 'grated cheese'],
#  ['spaghetti', 'grated cheese', 'herb & pepper'],
#  ['tomatoes', 'green tea', 'ground beef'],
#  ['ground beef', 'milk', 'herb & pepper'],
#  ['ground beef', 'mineral water', 'herb & pepper'],
#  ['ground beef', 'nan', 'herb & pepper'],
#  ['spaghetti', 'ground beef', 'herb & pepper'],
#  ['olive oil', 'ground beef', 'milk'],
#  ['soup', 'ground beef', 'milk'],
#  ['ground beef', 'nan', 'tomato sauce'],
#  ['pepper', 'ground beef', 'spaghetti'],
#  ['spaghetti', 'ground beef', 'shrimp'],
#  ['spaghetti', 'ground beef', 'tomato sauce'],
#  ['spaghetti', 'light cream', 'mineral water'],
#  ['light cream', 'olive oil', 'nan'],
#  ['soup', 'mineral water', 'milk'],
#  ['olive oil', 'shrimp', 'milk'],
#  ['soup', 'olive oil', 'milk'],
#  ['spaghetti', 'olive oil', 'milk'],
#  ['tomatoes', 'soup', 'milk'],
#  ['spaghetti', 'milk', 'whole wheat pasta'],
#  ['soup', 'mineral water', 'olive oil'],
#  ['mineral water', 'olive oil', 'whole wheat pasta'],
#  ['tomatoes', 'soup', 'mineral water'],
#  ['nan', 'olive oil', 'whole wheat pasta'],
#  ['pasta', 'nan', 'shrimp'],
#  ['spaghetti', 'pancakes', 'olive oil'],
#  ['tomatoes', 'spaghetti', 'olive oil'],
#  ['tomatoes', 'spaghetti', 'whole wheat rice'],
#  ['spaghetti', 'avocado', 'milk', 'nan'],
#  ['nan', 'burgers', 'milk', 'cake'],
#  ['nan', 'burgers', 'turkey', 'chocolate'],
#  ['nan', 'burgers', 'milk', 'turkey'],
#  ['tomatoes', 'frozen vegetables', 'nan', 'cake'],
#  ['spaghetti', 'ground beef', 'nan', 'cereals'],
#  ['ground beef', 'chicken', 'nan', 'milk'],
#  ['olive oil', 'chicken', 'nan', 'milk'],
#  ['pancakes', 'chicken', 'nan', 'milk'],
#  ['spaghetti', 'chicken', 'nan', 'olive oil'],
#  ['ground beef', 'eggs', 'mineral water', 'chocolate'],
#  ['spaghetti', 'ground beef', 'eggs', 'chocolate'],
#  ['ground beef', 'frozen vegetables', 'mineral water', 'chocolate'],
#  ['spaghetti', 'ground beef', 'frozen vegetables', 'chocolate'],
#  ['mineral water', 'frozen vegetables', 'milk', 'chocolate'],
#  ['spaghetti', 'frozen vegetables', 'milk', 'chocolate'],
#  ['shrimp', 'frozen vegetables', 'mineral water', 'chocolate'],
#  ['spaghetti', 'frozen vegetables', 'mineral water', 'chocolate'],
#  ['frozen vegetables', 'shrimp', 'nan', 'chocolate'],
#  ['ground beef', 'nan', 'herb & pepper', 'chocolate'],
#  ['ground beef', 'mineral water', 'milk', 'chocolate'],
#  ['soup', 'nan', 'milk', 'chocolate'],
#  ['spaghetti', 'mineral water', 'olive oil', 'chocolate'],
#  ['spaghetti', 'pancakes', 'mineral water', 'chocolate'],
#  ['spaghetti', 'mineral water', 'shrimp', 'chocolate'],
#  ['spaghetti', 'cooking oil', 'nan', 'ground beef'],
#  ['frozen vegetables', 'eggs', 'milk', 'mineral water'],
#  ['ground beef', 'eggs', 'nan', 'herb & pepper'],
#  ['mineral water', 'ground beef', 'eggs', 'milk'],
#  ['spaghetti', 'ground beef', 'eggs', 'mineral water'],
#  ['red wine', 'spaghetti', 'eggs', 'nan'],
#  ['french fries', 'ground beef', 'nan', 'herb & pepper'],
#  ['spaghetti', 'frozen smoothie', 'mineral water', 'milk'],
#  ['tomatoes', 'green tea', 'frozen vegetables', 'nan'],
#  ['mineral water', 'ground beef', 'frozen vegetables', 'milk'],
#  ['spaghetti', 'ground beef', 'frozen vegetables', 'milk'],
#  ['spaghetti', 'ground beef', 'frozen vegetables', 'mineral water'],
#  ['spaghetti', 'ground beef', 'frozen vegetables', 'nan'],
#  ['mineral water', 'olive oil', 'frozen vegetables', 'milk'],
#  ['mineral water', 'soup', 'frozen vegetables', 'milk'],
#  ['mineral water', 'spaghetti', 'frozen vegetables', 'milk'],
#  ['olive oil', 'frozen vegetables', 'milk', 'nan'],
#  ['soup', 'frozen vegetables', 'milk', 'nan'],
#  ['tomatoes', 'frozen vegetables', 'milk', 'nan'],
#  ['frozen vegetables', 'mineral water', 'nan', 'shrimp'],
#  ['spaghetti', 'frozen vegetables', 'mineral water', 'shrimp'],
#  ['tomatoes', 'spaghetti', 'frozen vegetables', 'mineral water'],
#  ['spaghetti', 'frozen vegetables', 'olive oil', 'nan'],
#  ['spaghetti', 'frozen vegetables', 'nan', 'shrimp'],
#  ['tomatoes', 'frozen vegetables', 'nan', 'shrimp'],
#  ['tomatoes', 'spaghetti', 'frozen vegetables', 'nan'],
#  ['spaghetti', 'ground beef', 'grated cheese', 'nan'],
#  ['spaghetti', 'grated cheese', 'nan', 'herb & pepper'],
#  ['tomatoes', 'green tea', 'nan', 'ground beef'],
#  ['ground beef', 'nan', 'milk', 'herb & pepper'],
#  ['ground beef', 'mineral water', 'nan', 'herb & pepper'],
#  ['spaghetti', 'ground beef', 'nan', 'herb & pepper'],
#  ['spaghetti', 'ground beef', 'mineral water', 'milk'],
#  ['olive oil', 'ground beef', 'nan', 'milk'],
#  ['soup', 'ground beef', 'nan', 'milk'],
#  ['spaghetti', 'ground beef', 'mineral water', 'olive oil'],
#  ['spaghetti', 'ground beef', 'mineral water', 'pancakes'],
#  ['spaghetti', 'ground beef', 'mineral water', 'tomatoes'],
#  ['pepper', 'ground beef', 'nan', 'spaghetti'],
#  ['spaghetti', 'ground beef', 'nan', 'shrimp'],
#  ['spaghetti', 'ground beef', 'nan', 'tomato sauce'],
#  ['spaghetti', 'light cream', 'mineral water', 'nan'],
#  ['soup', 'mineral water', 'milk', 'nan'],
#  ['spaghetti', 'olive oil', 'mineral water', 'milk'],
#  ['spaghetti', 'mineral water', 'milk', 'shrimp'],
#  ['tomatoes', 'spaghetti', 'mineral water', 'milk'],
#  ['olive oil', 'nan', 'milk', 'shrimp'],
#  ['soup', 'olive oil', 'nan', 'milk'],
#  ['spaghetti', 'olive oil', 'nan', 'milk'],
#  ['tomatoes', 'soup', 'nan', 'milk'],
#  ['spaghetti', 'nan', 'milk', 'whole wheat pasta'],
#  ['soup', 'mineral water', 'olive oil', 'nan'],
#  ['mineral water', 'olive oil', 'nan', 'whole wheat pasta'],
#  ['tomatoes', 'soup', 'mineral water', 'nan'],
#  ['spaghetti', 'pancakes', 'nan', 'olive oil'],
#  ['tomatoes', 'spaghetti', 'nan', 'olive oil'],
#  ['tomatoes', 'spaghetti', 'nan', 'whole wheat rice'],
#  ['ground beef', 'eggs', 'chocolate', 'mineral water', 'nan'],
#  ['ground beef', 'eggs', 'chocolate', 'spaghetti', 'nan'],
#  ['ground beef', 'mineral water', 'chocolate', 'frozen vegetables', 'nan'],
#  ['ground beef', 'chocolate', 'spaghetti', 'frozen vegetables', 'nan'],
#  ['milk', 'frozen vegetables', 'chocolate', 'mineral water', 'nan'],
#  ['milk', 'chocolate', 'spaghetti', 'frozen vegetables', 'nan'],
#  ['shrimp', 'mineral water', 'chocolate', 'frozen vegetables', 'nan'],
#  ['mineral water', 'chocolate', 'spaghetti', 'frozen vegetables', 'nan'],
#  ['ground beef', 'milk', 'chocolate', 'mineral water', 'nan'],
#  ['olive oil', 'chocolate', 'spaghetti', 'mineral water', 'nan'],
#  ['pancakes', 'chocolate', 'spaghetti', 'mineral water', 'nan'],
#  ['shrimp', 'chocolate', 'spaghetti', 'mineral water', 'nan'],
#  ['eggs', 'milk', 'mineral water', 'frozen vegetables', 'nan'],
#  ['ground beef', 'eggs', 'milk', 'mineral water', 'nan'],
#  ['ground beef', 'eggs', 'spaghetti', 'mineral water', 'nan'],
#  ['milk', 'frozen smoothie', 'spaghetti', 'mineral water', 'nan'],
#  ['ground beef', 'milk', 'frozen vegetables', 'mineral water', 'nan'],
#  ['ground beef', 'milk', 'spaghetti', 'frozen vegetables', 'nan'],
#  ['ground beef', 'mineral water', 'spaghetti', 'frozen vegetables', 'nan'],
#  ['milk', 'frozen vegetables', 'olive oil', 'mineral water', 'nan'],
#  ['soup', 'milk', 'frozen vegetables', 'mineral water', 'nan'],
#  ['milk', 'frozen vegetables', 'spaghetti', 'mineral water', 'nan'],
#  ['shrimp', 'mineral water', 'spaghetti', 'frozen vegetables', 'nan'],
#  ['mineral water', 'tomatoes', 'spaghetti', 'frozen vegetables', 'nan'],
#  ['ground beef', 'milk', 'spaghetti', 'mineral water', 'nan'],
#  ['ground beef', 'olive oil', 'spaghetti', 'mineral water', 'nan'],
#  ['ground beef', 'pancakes', 'spaghetti', 'mineral water', 'nan'],
#  ['ground beef', 'tomatoes', 'spaghetti', 'mineral water', 'nan'],
#  ['milk', 'olive oil', 'spaghetti', 'mineral water', 'nan'],
#  ['shrimp', 'milk', 'spaghetti', 'mineral water', 'nan'],
#  ['milk', 'tomatoes', 'spaghetti', 'mineral water', 'nan']]
